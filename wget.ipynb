# %%
# The distribution structure of the ftp archive is:
# /zone (GLOB|EURO)
# /sensor (merged|seawifs|meris|modis|viirsn|olcia|viirsj1|olcib)
# /binning period (day|8-day|month)
# /yyyy/mm/dd

# %%
# where is an example for downloading all the MERIS CDM binned products

# wget -r -l10 -t10 -A "L3b*_4_*MER_CDM*.nc" -w3 -Q1000m ftp://login:password@ftp.hermes.acri.fr/GLOB/meris/

#wget -r -l10 -t10 -A "L3m*_25_*CHL1_MO*.png" -w3 -Q1000m ftp://login:password@ftp.hermes.acri.fr/GLOB/merged/ The

# %%
wget -r -l10 -t10 -A "L3m*_25_*CHL1_MO*.png" -w3 -Q1000m ftp://login:password@ftp.hermes.acri.fr/GLOB/merged/ The

# %%
# !wget -r -A "L3m*_2*__GLOB_4_GSM-SWF_CHL1_DAY_00.nc" -w3 ftp://ftp_hermes:hermes%@ftp.hermes.acri.fr/975627288/
# Out:
# --2021-12-09 21:44:59--  ftp://ftp_hermes:*password*@ftp.hermes.acri.fr/975627288/
#            => ‘ftp.hermes.acri.fr/975627288/.listing’
# Resolving ftp.hermes.acri.fr (ftp.hermes.acri.fr)... 5.252.148.37
# Connecting to ftp.hermes.acri.fr (ftp.hermes.acri.fr)|5.252.148.37|:21... connected.
# Logging in as ftp_hermes ... Logged in!
# ==> SYST ... done.    ==> PWD ... done.
# ==> TYPE I ... done.  ==> CWD (1) /975627288 ... done.
# ==> PASV ... done.    ==> LIST ... done.
#
# ftp.hermes.acri.fr/     [ <=>                ]   1,82M   344KB/s    in 3m 26s
#
# 2021-12-09 21:48:31 (9,04 KB/s) - ‘ftp.hermes.acri.fr/975627288/.listing’ saved [1908877]
#
# Removed ‘ftp.hermes.acri.fr/975627288/.listing’.
# Rejecting ‘L3m_19970916__975627288_4_AV-SWF_CHL1_DAY_00.nc’.
# Rejecting ‘L3m_19970916__975627288_4_GSM-SWF_CHL1_DAY_00.nc’.
# Rejecting ‘L3m_19970919__975627288_4_AV-SWF_CHL1_DAY_00.nc’.
# Rejecting ‘L3m_19970919__975627288_4_GSM-SWF_CHL1_DAY_00.nc’.
# ...

# %%
# !wget --help
# Out:
# GNU Wget 1.20.3, a non-interactive network retriever.
# Usage: wget [OPTION]... [URL]...
#
# Mandatory arguments to long options are mandatory for short options too.
#
# Startup:
#   -V,  --version                   display the version of Wget and exit
#   -h,  --help                      print this help
#   -b,  --background                go to background after startup
#   -e,  --execute=COMMAND           execute a `.wgetrc'-style command
#
# Logging and input file:
#   -o,  --output-file=FILE          log messages to FILE
#   -a,  --append-output=FILE        append messages to FILE
#   -d,  --debug                     print lots of debugging information
#   -q,  --quiet                     quiet (no output)
#   -v,  --verbose                   be verbose (this is the default)
#   -nv, --no-verbose                turn off verboseness, without being quiet
#        --report-speed=TYPE         output bandwidth as TYPE.  TYPE can be bits
# ...
